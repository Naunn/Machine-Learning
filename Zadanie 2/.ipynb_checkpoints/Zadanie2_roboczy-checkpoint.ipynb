# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# from dfply import *
# import re

# %% [markdown]
# # Data mining

# %%
# dane dotyczące sprzedaży gier komputerowych (również w wersjach na inne platformy)
df = pd.read_csv("VideoGamesSales.csv")
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
# Rank            16598 non-null int64
# Name            16598 non-null object
# Platform        16598 non-null object
# Year            16327 non-null float64
# Genre           16598 non-null object
# Publisher       16540 non-null object
# NA_Sales        16598 non-null float64
# EU_Sales        16598 non-null float64
# JP_Sales        16598 non-null float64
# Other_Sales     16598 non-null float64
# Global_Sales    16598 non-null float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB
#                 Rank                         Name Platform          Year  \
# count   16598.000000                        16598    16598  16327.000000
# unique           NaN                        11493       31           NaN
# top              NaN  Need for Speed: Most Wanted       DS           NaN
# ...

# %%
df.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df.head(20)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %%
df['Publisher'] = df['Publisher'].fillna('No data')
df.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher         0
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
# df[df.isna().any(axis=1)] # gdziekolwiek NaN w danych
df[df['Year'].isna()]
# Out:
#         Rank                                         Name Platform  Year  \
# 179      180                              Madden NFL 2004      PS2   NaN
# 377      378                             FIFA Soccer 2004      PS2   NaN
# 431      432                   LEGO Batman: The Videogame      Wii   NaN
# 470      471                   wwe Smackdown vs. Raw 2006      PS2   NaN
# 607      608                               Space Invaders     2600   NaN
# 624      625                                    Rock Band     X360   NaN
# 649      650     Frogger's Adventures: Temple of the Frog      GBA   NaN
# 652      653  LEGO Indiana Jones: The Original Adventures      Wii   NaN
# 711      713                               Call of Duty 3      Wii   NaN
# 782      784                                    Rock Band      Wii   NaN
# 1126    1128                      Call of Duty: Black Ops       PC   NaN
# 1133    1135                                    Rock Band      PS3   NaN
# ...

# %%
df[df['Name']=='Freaky Flyers']
# Out:
#         Rank           Name Platform    Year   Genre     Publisher  NA_Sales  \
# 10553  10555  Freaky Flyers      PS2  2003.0  Racing  Midway Games      0.05
# 14459  14462  Freaky Flyers       XB  2003.0  Racing  Midway Games      0.02
# 16307  16310  Freaky Flyers       GC     NaN  Racing       Unknown      0.01
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 10553      0.04       0.0         0.01          0.10
# 14459      0.01       0.0         0.00          0.03
# 16307      0.00       0.0         0.00          0.01

# %%
df[df['Name'].str.match('.*([1-3][0-9]{3})') & pd.isna(df['Year'])]
# Out:
#         Rank                               Name Platform  Year     Genre  \
# 179      180                    Madden NFL 2004      PS2   NaN    Sports
# 377      378                   FIFA Soccer 2004      PS2   NaN    Sports
# 470      471         wwe Smackdown vs. Raw 2006      PS2   NaN  Fighting
# 1649    1651                NASCAR Thunder 2003      PS2   NaN    Racing
# 2586    2588     PES 2009: Pro Evolution Soccer      PSP   NaN    Sports
# 3501    3503                    Madden NFL 2002       XB   NaN    Sports
# 4797    4799                   NFL GameDay 2003      PS2   NaN    Sports
# 5162    5164                      NBA Live 2003       XB   NaN    Sports
# 5240    5242                 Tomb Raider (2013)       PC   NaN    Action
# 5669    5671             All-Star Baseball 2005      PS2   NaN    Sports
# 5901    5903                      NBA Live 2003       GC   NaN    Sports
# 8929    8931             All-Star Baseball 2005       XB   NaN    Sports
# ...

# %%
# uzupelnienie rokiem z nazwy (wyrażenia regularne)
# df[df['Year'].isna() & df['Name'].str.match('.*([1-3][0-9]{3})')]
df['Year_str'] = df['Name'].str.extract('.*([1-3][0-9]{3})').astype(float)-1
df[pd.isna(df['Year'])]
# Out:
#         Rank                                         Name Platform  Year  \
# 179      180                              Madden NFL 2004      PS2   NaN
# 377      378                             FIFA Soccer 2004      PS2   NaN
# 431      432                   LEGO Batman: The Videogame      Wii   NaN
# 470      471                   wwe Smackdown vs. Raw 2006      PS2   NaN
# 607      608                               Space Invaders     2600   NaN
# 624      625                                    Rock Band     X360   NaN
# 649      650     Frogger's Adventures: Temple of the Frog      GBA   NaN
# 652      653  LEGO Indiana Jones: The Original Adventures      Wii   NaN
# 711      713                               Call of Duty 3      Wii   NaN
# 782      784                                    Rock Band      Wii   NaN
# 1126    1128                      Call of Duty: Black Ops       PC   NaN
# 1133    1135                                    Rock Band      PS3   NaN
# ...

# %%
df['Year_new'] = np.where(pd.isna(df['Year']), df['Year_str'], df['Year'])
df['Year'] = df['Year_new']
df = df.drop(['Year_str','Year_new'], axis=1)
df[pd.isna(df['Year'])]
# Out:
#         Rank                                         Name Platform  Year  \
# 431      432                   LEGO Batman: The Videogame      Wii   NaN
# 607      608                               Space Invaders     2600   NaN
# 624      625                                    Rock Band     X360   NaN
# 649      650     Frogger's Adventures: Temple of the Frog      GBA   NaN
# 652      653  LEGO Indiana Jones: The Original Adventures      Wii   NaN
# 711      713                               Call of Duty 3      Wii   NaN
# 782      784                                    Rock Band      Wii   NaN
# 1126    1128                      Call of Duty: Black Ops       PC   NaN
# 1133    1135                                    Rock Band      PS3   NaN
# 1303    1305                               Triple Play 99       PS   NaN
# 1433    1435                 LEGO Harry Potter: Years 5-7      Wii   NaN
# 1498    1500                   LEGO Batman: The Videogame      PSP   NaN
# ...

# %%
df.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            254
# Genre             0
# Publisher         0
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df[df['Name'].str.match('.*([1-3][0-9]{3})')]
# Out:
#         Rank                                               Name Platform  \
# 92        93                       Star Wars Battlefront (2015)      PS4
# 179      180                                    Madden NFL 2004      PS2
# 204      205                                       Warzone 2100       PS
# 238      239                                    Madden NFL 2005      PS2
# 249      250          Winning Eleven: Pro Evolution Soccer 2007      PS2
# 279      280                                    Madden NFL 2003      PS2
# 323      324     Mario & Sonic at the London 2012 Olympic Games      Wii
# 327      328                                    Just Dance 2014      Wii
# 334      335                                   FIFA Soccer 2005      PS2
# 348      349                          Pro Evolution Soccer 2008      PS2
# 377      378                                   FIFA Soccer 2004      PS2
# 378      379                       Star Wars Battlefront (2015)     XOne
# ...

# %%
df[df['Name'] == 'Madden NFL 2004']
# Out:
#       Rank             Name Platform    Year   Genre        Publisher  \
# 179    180  Madden NFL 2004      PS2  2003.0  Sports  Electronic Arts
# 1881  1883  Madden NFL 2004       XB  2003.0  Sports  Electronic Arts
# 3896  3898  Madden NFL 2004       GC  2003.0  Sports  Electronic Arts
# 5712  5714  Madden NFL 2004      GBA  2003.0  Sports  Electronic Arts
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 179       4.26      0.26      0.01         0.71          5.23
# 1881      1.02      0.02      0.00         0.05          1.09
# 3896      0.40      0.10      0.00         0.01          0.51
# 5712      0.22      0.08      0.00         0.01          0.31

# %%
df[df['Name'].str.match("Without Warning")]
# Out:
#         Rank             Name Platform    Year    Genre Publisher  NA_Sales  \
# 13998  14000  Without Warning      PS2  2005.0  Shooter    Capcom      0.02
# 15717  15720  Without Warning       XB     NaN  Shooter    Capcom      0.01
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 13998      0.01       0.0          0.0          0.04
# 15717      0.00       0.0          0.0          0.02

# %%
df['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
# dodanie kolumny z dodaniem daty premiery platformy (za rok wydania przyjmuje sie rok wydania w kraju producenta)
platform_year = {
    "Wii": 2006.0,
    "NES": 1983.0,
    "GB": 1989.0,
    "DS": 2004.0,
    "X360": 2005.0,
    "PS3": 2006.0,
    "PS2": 2000.0,
    "SNES": 1990.0,
    "GBA": 2001.0,
    "3DS": 2011.0,
    "PS4": 2013.0,
    "N64": 1996.0,
    "PS": 1994.0,
    "XB": 2001.0,
    "PC": 1985.0,
    "2600": 1977.0,
    "PSP": 2004.0,
    "XOne": 2013.0,
    "GC": 2001.0,
    "WiiU": 2012.0,
    "GEN": 1988.0, # Sega Genesis
    "DC": 1998.0, #Dreamcast
    "PSV": 2011.0,
    "SAT": 1994.0, # Sega Saturn
    "SCD": 1991.0, # Sega CD
    "WS": 1999.0, # WonderSwan
    "NG": 1990.0, # Neo Geo
    "TG16": 1987.0, # TurboGrafx-16
    "3DO": 1993.0, # 3DO Interactive Multiplayer (Panasonic, Sanyo, GoldStar)
    "GG": 1990.0, # Sega Game Gear
    "PCFX": 1994.0
}
platform_year
# Out:
# {'Wii': 2006.0,
#  'NES': 1983.0,
#  'GB': 1989.0,
#  'DS': 2004.0,
#  'X360': 2005.0,
#  'PS3': 2006.0,
#  'PS2': 2000.0,
#  'SNES': 1990.0,
#  'GBA': 2001.0,
#  '3DS': 2011.0,
#  'PS4': 2013.0,
#  'N64': 1996.0,
#  'PS': 1994.0,
#  'XB': 2001.0,
#  'PC': 1985.0,
#  '2600': 1977.0,
#  'PSP': 2004.0,
#  'XOne': 2013.0,
#  'GC': 2001.0,
#  'WiiU': 2012.0,
#  'GEN': 1988.0,
#  'DC': 1998.0,
#  'PSV': 2011.0,
#  'SAT': 1994.0,
#  'SCD': 1991.0,
#  'WS': 1999.0,
#  'NG': 1990.0,
#  'TG16': 1987.0,
#  '3DO': 1993.0,
#  'GG': 1990.0,
#  'PCFX': 1994.0}

# %%
platform_year[df['Platform'][0]]
# Out:
# 2006.0

# %%
def plat_year(platf: str):
    return platform_year[platf]
df['Platform_Year'] = df['Platform'].map(lambda x: plat_year(x))
df.head(20)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %%
# sprawdzenie wszystkich tytułów, czy nie występują pozycje z premiera gry przed premiera platformy
df['Year>Platform_Year'] = np.where(df['Year'] < df['Platform_Year'], 1, 0)
df[df['Year>Platform_Year'] == 1]
# Out:
#         Rank                                    Name Platform    Year  \
# 1350    1352                      Disney's DuckTales       GB  1988.0
# 2083    2085                          NFL Fever 2002       XB  2000.0
# 12270  12272  ESPN Winter X-Games: Snowboarding 2002      GBA  2000.0
# 15867  15870     Strongest Tokyo University Shogi DS       DS  1985.0
#
#           Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 1350   Platform                        Capcom      0.82      0.23      0.35
# 2083     Sports        Microsoft Game Studios      0.74      0.21      0.00
# 12270    Sports  Konami Digital Entertainment      0.05      0.02      0.00
# 15867    Action                         Mycom      0.00      0.00      0.02
#
#        Other_Sales  Global_Sales  Platform_Year  Year>Platform_Year
# 1350          0.03          1.43         1989.0                   1
# 2083          0.04          0.99         2001.0                   1
# ...

# %%
# Korekta dat
df.loc[df['Year>Platform_Year'] == 1, 'Year'] = df.loc[df['Year>Platform_Year'] == 1, 'Platform_Year']
df['Year>Platform_Year'] = np.where(df['Year'] < df['Platform_Year'], 1, 0)
df[df['Year>Platform_Year'] == 1]
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales, Platform_Year, Year>Platform_Year]
# Index: []

# %%
df = df.drop(['Year>Platform_Year'], axis=1)
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Platform_Year
# 0     41.49     29.02      3.77         8.46         82.74         2006.0
# 1     29.08      3.58      6.81         0.77         40.24         1983.0
# 2     15.85     12.88      3.79         3.31         35.82         2006.0
# 3     15.75     11.01      3.28         2.96         33.00         2006.0
# 4     11.27      8.89     10.22         1.00         31.37         1989.0

# %% [markdown]
# ## 1. Data wydania musi byc niemniejsza niz wydania platformy
# ## 2. Jezeli gra wyszla przed premiera platformy, to przyjmuj date wydania platformy
# ## 3. Jezeli wyszla po wydaniu platformy (jest inna pozycja) to daj date innej pozycji
# ## - Poszukac podobienstw po tutule przed znakiem specjalnym
# ## - Utworzyc konkurencyjne grupy platform
# ## - Dla ostatnich moze zrobic losowe dobranie lat poprzez jakis losowy proces, albo patrzac po wydawcy
# ## - Klastrowanie raczej po wedlug "szczegolowowsci": Kraj(wydawcy) > Wydawca > Platforma > Tytul
# ## - Ignorujemy zaszle generacje konsol, jedynie mozna brac poprawke na tytuly, ktore cieszyly sie duza popularnoscia (nostalgia)

# %%
df[pd.isna(df['Year'])]
# Out:
#         Rank                                         Name Platform  Year  \
# 431      432                   LEGO Batman: The Videogame      Wii   NaN
# 607      608                               Space Invaders     2600   NaN
# 624      625                                    Rock Band     X360   NaN
# 649      650     Frogger's Adventures: Temple of the Frog      GBA   NaN
# 652      653  LEGO Indiana Jones: The Original Adventures      Wii   NaN
# 711      713                               Call of Duty 3      Wii   NaN
# 782      784                                    Rock Band      Wii   NaN
# 1126    1128                      Call of Duty: Black Ops       PC   NaN
# 1133    1135                                    Rock Band      PS3   NaN
# 1303    1305                               Triple Play 99       PS   NaN
# 1433    1435                 LEGO Harry Potter: Years 5-7      Wii   NaN
# 1498    1500                   LEGO Batman: The Videogame      PSP   NaN
# ...

# %%
df[df['Name']=='Runaway: A Twist of Fate']
# Out:
#         Rank                      Name Platform    Year      Genre  \
# 13465  13467  Runaway: A Twist of Fate       PC  2009.0  Adventure
# 15316  15319  Runaway: A Twist of Fate       DS     NaN  Adventure
#
#                     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 13465  Focus Home Interactive       0.0      0.04       0.0         0.01
# 15316  Focus Home Interactive       0.0      0.02       0.0         0.00
#
#        Global_Sales  Platform_Year
# 13465          0.04         1985.0
# 15316          0.02         2004.0

# %%
df[df['Name'].isin(df.loc[pd.isna(df['Year'])].Name.unique())].sort_values(['Name'])
# Out:
#         Rank                                        Name Platform    Year  \
# 4825    4827      AKB1/48: Idol to Guam de Koishitara...      PSP  2011.0
# 16198  16201      AKB1/48: Idol to Guam de Koishitara...     X360     NaN
# 11076  11078                Action Man-Operation Extreme       PS     NaN
# 3217    3219                  Advance Wars: Days of Ruin       DS     NaN
# 1513    1515                                   Adventure     2600     NaN
# 16246  16249                Agarest Senki: Re-appearance      PS3     NaN
# 2113    2115                              Air-Sea Battle     2600     NaN
# 12129  12131                    Alex Rider: Stormbreaker       DS     NaN
# 8553    8555        Alone in the Dark: The New Nightmare       PS     NaN
# 16249  16252                Aquaman: Battle for Atlantis       GC  2003.0
# 16065  16068                Aquaman: Battle for Atlantis       XB     NaN
# 10494  10496      Atsumare! Power Pro Kun no DS Koushien       DS     NaN
# ...

# %%
df.loc[(df['Name'] == 'Hitman 2: Silent Assassin') & (df['Platform'].isin(['PS2', 'XB']))]
# Out:
#       Rank                       Name Platform    Year   Genre  \
# 482    483  Hitman 2: Silent Assassin      PS2  2002.0  Action
# 1697  1699  Hitman 2: Silent Assassin       XB     NaN  Action
#
#               Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 482   Eidos Interactive      1.36      1.15      0.04         0.41
# 1697  Eidos Interactive      0.76      0.38      0.00         0.05
#
#       Global_Sales  Platform_Year
# 482           2.96         2000.0
# 1697          1.19         2001.0

# %%
df.loc[(df['Name'] == 'Hitman 2: Silent Assassin')]
# Out:
#       Rank                       Name Platform    Year   Genre  \
# 482    483  Hitman 2: Silent Assassin      PS2  2002.0  Action
# 1697  1699  Hitman 2: Silent Assassin       XB     NaN  Action
# 9501  9503  Hitman 2: Silent Assassin       GC  2003.0  Action
#
#               Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 482   Eidos Interactive      1.36      1.15      0.04         0.41
# 1697  Eidos Interactive      0.76      0.38      0.00         0.05
# 9501  Eidos Interactive      0.10      0.03      0.00         0.00
#
#       Global_Sales  Platform_Year
# 482           2.96         2000.0
# 1697          1.19         2001.0
# 9501          0.13         2001.0

# %%
len(set(df[df['Name'] == 'Aquaman: Battle for Atlantis'].Year))
# Out:
# 2

# %%
len(set([2002.0])) == 2
# Out:
# False

# %%
max(set([2002.0])) >= max(set([2000.0, 2001.0]))
# Out:
# True

# %%
df.loc[(pd.isna(df['Year']) & (df['Platform'].isin(['PS', 'XB']))]
# Out:
#   File "<ipython-input-30-ae6d1997b439>", line 1
#     df.loc[(pd.isna(df['Year']) & (df['Platform'].isin(['PS', 'XB']))]
#                                                                      ^
# SyntaxError: invalid syntax

# %%
df[df['Name'].isin(df.loc[pd.isna(df['Year'])].Name.unique())].sort_values(['Name'])
# Out:
#         Rank                                        Name Platform    Year  \
# 4825    4827      AKB1/48: Idol to Guam de Koishitara...      PSP  2011.0
# 16198  16201      AKB1/48: Idol to Guam de Koishitara...     X360     NaN
# 11076  11078                Action Man-Operation Extreme       PS     NaN
# 3217    3219                  Advance Wars: Days of Ruin       DS     NaN
# 1513    1515                                   Adventure     2600     NaN
# 16246  16249                Agarest Senki: Re-appearance      PS3     NaN
# 2113    2115                              Air-Sea Battle     2600     NaN
# 12129  12131                    Alex Rider: Stormbreaker       DS     NaN
# 8553    8555        Alone in the Dark: The New Nightmare       PS     NaN
# 16249  16252                Aquaman: Battle for Atlantis       GC  2003.0
# 16065  16068                Aquaman: Battle for Atlantis       XB     NaN
# 10494  10496      Atsumare! Power Pro Kun no DS Koushien       DS     NaN
# ...

# %%
def PSvsXB(names: list, gen: int):
    all_names = set(df['Name'])
    if gen == 2:
        ps, xbox = 'PS2', 'XB'
    elif gen == 3:
        ps, xbox = 'PS3', 'X360'
    elif gen == 4:
        ps, xbox = 'PS4', 'XOne'
    else:
        return "Brak odpowiedniej generacji konsol!"
    for name in names:
        if name in all_names:
            a = df.loc[(df['Name'] == name) & (df['Platform'].isin([ps, xbox]))] # tabela z zawieraniem platform ps i xb
            if len(a) > 1: # jezeli wystepuja obie platformy
                try:
                    b = list({x for x in a.Year if pd.notna(x)})[0] # rok
                    df.loc[(df['Name'] == name) & (df['Platform'].isin([ps, xbox]))] = df.loc[(df['Name'] == name) & (df['Platform'].isin([ps, xbox]))].fillna(b)
                    #df.loc[(df['Name'] == name) & (df['Platform'].isin(['PS2', 'XB']))].Year = df.loc[(df['Name'] == name) & (df['Platform'].isin(['PS2', 'XB']))].Year.replace(np.nan, b) #= np.where(pd.isna(a.Year), b, a.Year)
                except:
                    continue

# %%
PSvsXB(set(df[pd.isna(df['Year'])].Name), 2)
df.isna().sum()
# Out:
# Rank               0
# Name               0
# Platform           0
# Year             241
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Platform_Year      0
# dtype: int64

# %%
PSvsXB(set(df[pd.isna(df['Year'])].Name), 3)
df.isna().sum()
# Out:
# Rank               0
# Name               0
# Platform           0
# Year             228
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Platform_Year      0
# dtype: int64

# %%
PSvsXB(set(df[pd.isna(df['Year'])].Name), 4)
df.isna().sum()
# Out:
# Rank               0
# Name               0
# Platform           0
# Year             228
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Platform_Year      0
# dtype: int64

# %%
df[df['Name'].isin(df.loc[pd.isna(df['Year'])].Name.unique())].sort_values(['Name'])
# Out:
#         Rank                                               Name Platform  \
# 4825    4827             AKB1/48: Idol to Guam de Koishitara...      PSP
# 16198  16201             AKB1/48: Idol to Guam de Koishitara...     X360
# 11076  11078                       Action Man-Operation Extreme       PS
# 3217    3219                         Advance Wars: Days of Ruin       DS
# 1513    1515                                          Adventure     2600
# 16246  16249                       Agarest Senki: Re-appearance      PS3
# 2113    2115                                     Air-Sea Battle     2600
# 12129  12131                           Alex Rider: Stormbreaker       DS
# 8553    8555               Alone in the Dark: The New Nightmare       PS
# 16249  16252                       Aquaman: Battle for Atlantis       GC
# 16065  16068                       Aquaman: Battle for Atlantis       XB
# 10494  10496             Atsumare! Power Pro Kun no DS Koushien       DS
# ...

# %%
def biggest_year(names: list):
    all_names = set(df['Name'])
    for name in names:
        if name in all_names:
            a = {x for x in set(df.loc[df['Name'] == name].Year) if pd.notna(x)}
            if len(a) == 1:
                b = {x for x in set(df.loc[df['Name'] == name].Platform_Year) if pd.notna(x)}
                if max(a) >= max(b):
                     df.loc[df['Name'] == name] =  df.loc[df['Name'] == name].fillna(max(a))

# %%
biggest_year(set(df[pd.isna(df['Year'])].Name))
df.isna().sum()
# Out:
# Rank               0
# Name               0
# Platform           0
# Year             149
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Platform_Year      0
# dtype: int64

# %%
df[df['Name'].isin(df.loc[pd.isna(df['Year'])].Name.unique())].sort_values(['Name'], ascending = False)
# Out:
#         Rank                                               Name Platform  \
# 8899    8901                                     eJay Clubworld      PS2
# 11409  11411                           Zero: Tsukihami no Kamen      Wii
# 15476  15479         Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)      Wii
# 7351    7353                     Yu Yu Hakusho: Dark Tournament      PS2
# 12135  12137                                     Yoostar on MTV     X360
# 2134    2136                                           Yakuza 4      PS3
# 15606  15609         Writing and Speaking Beautiful Japanese DS       DS
# 14997  15000                        Wii de Asobu: Metroid Prime      Wii
# 14999  15002                        Wii de Asobu: Metroid Prime      Wii
# 2173    2175                                   Wheel of Fortune      PS2
# 2076    2078                                   Wheel of Fortune      Wii
# 4506    4508                                   Wheel of Fortune       DS
# ...

# %%
'3DS' in set(df.loc[df['Name'] == 'The Smurfs'].Platform)
# Out:
# False

# %%
len({x for x in set(df.loc[df['Name'] == 'Combat'].Year) if pd.notna(x)})
# Out:
# 0

# %%
def DS(names: list):
    all_names = set(df['Name'])
    for name in names:
        if name in all_names:
            a = {x for x in set(df.loc[df['Name'] == name].Year) if pd.notna(x)}
            try:
                if ((len(a) >= 1) & ('3DS' in set(df.loc[df['Name'] == name].Platform))) or ((len(a) == 0) & ('3DS' in set(df.loc[df['Name'] == name].Platform))):
                    b = df.loc[(df['Name'] == name) & (df['Platform'] == '3DS')].Platform_Year
                    df.loc[(df['Name'] == name) & (df['Platform'] == '3DS')] = df.loc[(df['Name'] == name) & (df['Platform'] == '3DS')].fillna(list(b)[0])                 
            except:
                continue

# %%
DS(set(df[pd.isna(df['Year'])].Name))
df.isna().sum()
# Out:
# Rank               0
# Name               0
# Platform           0
# Year             141
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Platform_Year      0
# dtype: int64

# %%
df[df['Name'].isin(df.loc[pd.isna(df['Year'])].Name.unique())].sort_values(['Year'], ascending = False)
# Out:
#         Rank                                               Name Platform  \
# 2076    2078                                   Wheel of Fortune      Wii
# 4506    4508                                   Wheel of Fortune       DS
# 13893  13895                  WRC: FIA World Rally Championship      PSP
# 14490  14493                                     Smashing Drive      GBA
# 10390  10392                                     Space Invaders      GBA
# 14000  14002                                     Smashing Drive       XB
# 8587    8589                                     Space Invaders      N64
# 1579    1581                                   Wheel of Fortune       PS
# 6687    6689                                   Wheel of Fortune      N64
# 4293    4295                                     Space Invaders     SNES
# 607      608                                     Space Invaders     2600
# 624      625                                          Rock Band     X360
# ...

# %%
df[df['Name'].isin(df.loc[pd.isna(df['Year'])].Name.unique())].sort_values(['Platform_Year'], ascending = False)
# Out:
#         Rank                                               Name Platform  \
# 5870    5872                    Disgaea 3: Absence of Detention      PSV
# 14046  14048                                             Swords      Wii
# 14997  15000                        Wii de Asobu: Metroid Prime      Wii
# 14876  14879            Combat Wings: The Great Battles of WWII      Wii
# 4536    4538                                       NHL Slapshot      Wii
# 4858    4860                            Silent Hill: Homecoming      PS3
# 4934    4936              Robert Ludlum's The Bourne Conspiracy      PS3
# 5302    5304      Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)      Wii
# 12879  12881                            Reader Rabbit 2nd Grade      Wii
# 6926    6928                            DanceDanceRevolution II      Wii
# 6966    6968                                 Big Beach Sports 2      Wii
# 12666  12668                               Flip's Twisted World      Wii
# ...

# %%
df[df['Name'] == 'Disgaea 3: Absence of Detention'] = df[df['Name'] == 'Disgaea 3: Absence of Detention'].fillna(2011.0)
df[df['Name'] == 'Disgaea 3: Absence of Detention']
# Out:
#       Rank                             Name Platform    Year         Genre  \
# 5870  5872  Disgaea 3: Absence of Detention      PSV  2011.0  Role-Playing
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 5870  Nippon Ichi Software      0.13      0.06      0.07         0.04
#
#       Global_Sales  Platform_Year
# 5870           0.3         2011.0

# %%
df.isna().sum()
# Out:
# Rank               0
# Name               0
# Platform           0
# Year             140
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Platform_Year      0
# dtype: int64

# %%
df = df[pd.isna(df['Year']) != True]

# %%
df.isna().sum()
# Out:
# Rank             0
# Name             0
# Platform         0
# Year             0
# Genre            0
# Publisher        0
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# Global_Sales     0
# Platform_Year    0
# dtype: int64

# %%
# funkcja zliczająca liczbę wystepowań elementu
def count_elements(seq: list) -> dict:
    hist = {}
    for i in seq:
        hist[i] = hist.get(i, 0) + 1
    return hist

# %%
df2000 = df[df['Year'] >= 2000.0]
df2010 = df[df['Year'] >= 2010.0]

# %%
platform = dict(sorted(count_elements(df["Platform"]).items(), key=lambda item: item[1], reverse = True))

plt.figure(figsize=(100, 7))

plt.subplot(131)
plt.bar(platform.keys(), platform.values())
plt.grid(True)

plt.title("Number of occurrences per platform")

plt.show()

# %%
platform2000 = dict(sorted(count_elements(df2000["Platform"]).items(), key=lambda item: item[1], reverse = True))

plt.figure(figsize=(100, 7))

plt.subplot(131)
plt.bar(platform2000.keys(), platform2000.values())
plt.grid(True)

plt.title("Number of occurrences per platform (>2000)")

plt.show()

# %%
platform2010 = dict(sorted(count_elements(df2010["Platform"]).items(), key=lambda item: item[1], reverse = True))

plt.figure(figsize=(100, 7))

plt.subplot(131)
plt.bar(platform2010.keys(), platform2010.values())
plt.grid(True)

plt.title("Number of occurrences per platform (>2010)")

plt.show()

# %%
genre = dict(sorted(count_elements(df["Genre"]).items(), key=lambda item: item[1], reverse = True))

plt.figure(figsize=(100, 7))

plt.subplot(131)
plt.bar(genre.keys(), genre.values())
plt.grid(True)

plt.title("Number of occurrences per genre")

plt.show()

# %%
genre2000 = dict(sorted(count_elements(df2000["Genre"]).items(), key=lambda item: item[1], reverse = True))

plt.figure(figsize=(100, 7))

plt.subplot(131)
plt.bar(genre2000.keys(), genre2000.values())
plt.grid(True)

plt.title("Number of occurrences per genre (>2000)")

plt.show()

# %%
genre2010 = dict(sorted(count_elements(df2010["Genre"]).items(), key=lambda item: item[1], reverse = True))

plt.figure(figsize=(100, 7))

plt.subplot(131)
plt.bar(genre2010.keys(), genre2010.values())
plt.grid(True)

plt.title("Number of occurrences per genre (>2010)")

plt.show()

# %%
publisher = dict(sorted(count_elements(df["Publisher"]).items(), key=lambda item: item[1], reverse = True))
publisher_top = list(publisher.items())[:50]
names = []
values = []
for i in range(len(publisher_top)):
    names.append(publisher_top[i][0])
    values.append(publisher_top[i][1])
    
plt.figure(figsize=(100, 7))

plt.subplot(131)
plt.bar(names, values)
plt.grid(True)

plt.xticks(rotation='vertical')
plt.title("Number of occurrences per publisher")

plt.show()

# %%
publisher2000 = dict(sorted(count_elements(df2000["Publisher"]).items(), key=lambda item: item[1], reverse = True))
publisher2000_top = list(publisher.items())[:50]
names = []
values = []
for i in range(len(publisher2000_top)):
    names.append(publisher2000_top[i][0])
    values.append(publisher2000_top[i][1])
    
plt.figure(figsize=(100, 7))

plt.subplot(131)
plt.bar(names, values)
plt.grid(True)

plt.xticks(rotation='vertical')
plt.title("Number of occurrences per publisher (>2000)")

plt.show()

# %%
publisher2010 = dict(sorted(count_elements(df2010["Publisher"]).items(), key=lambda item: item[1], reverse = True))
publisher2010_top = list(publisher.items())[:50]
names = []
values = []
for i in range(len(publisher2010_top)):
    names.append(publisher2010_top[i][0])
    values.append(publisher2010_top[i][1])
    
plt.figure(figsize=(100, 7))

plt.subplot(131)
plt.bar(names, values)
plt.grid(True)

plt.xticks(rotation='vertical')
plt.title("Number of occurrences per publisher (>2010)")

plt.show()

# %%
sales = df.groupby('Platform')['Global_Sales'].sum().sort_values(ascending = False)
names = []
values = []
for i in range(len(sales)):
    names.append(sales.keys()[i])
    values.append(sales[i])

plt.figure(figsize=(100, 7))

plt.subplot(131)
plt.bar(names, values)
plt.grid(True)

plt.title("Sum of global sales per platform")

plt.show()

# %%
sales2000 = df2000.groupby('Platform')['Global_Sales'].sum().sort_values(ascending = False)
names = []
values = []
for i in range(len(sales2000)):
    names.append(sales2000.keys()[i])
    values.append(sales2000[i])

plt.figure(figsize=(100, 7))

plt.subplot(131)
plt.bar(names, values)
plt.grid(True)

plt.title("Sum of global sales per platform (>2000)")

plt.show()

# %%
sales2010 = df2010.groupby('Platform')['Global_Sales'].sum().sort_values(ascending = False)
names = []
values = []
for i in range(len(sales2010)):
    names.append(sales2010.keys()[i])
    values.append(sales2010[i])

plt.figure(figsize=(100, 7))

plt.subplot(131)
plt.bar(names, values)
plt.grid(True)

plt.title("Sum of global sales per platform (>2010)")

plt.show()

# %%
sales = df.groupby('Genre')['Global_Sales'].sum().sort_values(ascending = False)
names = []
values = []
for i in range(len(sales)):
    names.append(sales.keys()[i])
    values.append(sales[i])

plt.figure(figsize=(100, 7))

plt.subplot(131)
plt.bar(names, values)
plt.grid(True)

plt.xticks(rotation='vertical')
plt.title("Sum of global sales per genre")

plt.show()

# %%
sales2000 = df2000.groupby('Genre')['Global_Sales'].sum().sort_values(ascending = False)
names = []
values = []
for i in range(len(sales2000)):
    names.append(sales2000.keys()[i])
    values.append(sales2000[i])

plt.figure(figsize=(100, 7))

plt.subplot(131)
plt.bar(names, values)
plt.grid(True)

plt.xticks(rotation='vertical')
plt.title("Sum of global sales per genre (>2000)")

plt.show()

# %%
sales2010 = df2010.groupby('Genre')['Global_Sales'].sum().sort_values(ascending = False)
names = []
values = []
for i in range(len(sales2010)):
    names.append(sales2010.keys()[i])
    values.append(sales2010[i])

plt.figure(figsize=(100, 7))

plt.subplot(131)
plt.bar(names, values)
plt.grid(True)

plt.xticks(rotation='vertical')
plt.title("Sum of global sales per genre (>2010)")

plt.show()

# %%
sales = df.groupby('Publisher')['Global_Sales'].sum().sort_values(ascending = False)[:50]
names = []
values = []
for i in range(len(sales)):
    names.append(sales.keys()[i])
    values.append(sales[i])

plt.figure(figsize=(100, 7))

plt.subplot(131)
plt.bar(names, values)
plt.grid(True)

plt.xticks(rotation='vertical')
plt.title("Sum of global sales per publisher")

plt.show()

# %%
sales2000 = df2000.groupby('Publisher')['Global_Sales'].sum().sort_values(ascending = False)[:50]
names = []
values = []
for i in range(len(sales2000)):
    names.append(sales2000.keys()[i])
    values.append(sales2000[i])

plt.figure(figsize=(100, 7))

plt.subplot(131)
plt.bar(names, values)
plt.grid(True)

plt.xticks(rotation='vertical')
plt.title("Sum of global sales per publisher (>2000)")

plt.show()

# %%
sales2010 = df2010.groupby('Publisher')['Global_Sales'].sum().sort_values(ascending = False)[:50]
names = []
values = []
for i in range(len(sales2010)):
    names.append(sales2010.keys()[i])
    values.append(sales2010[i])

plt.figure(figsize=(100, 7))

plt.subplot(131)
plt.bar(names, values)
plt.grid(True)

plt.xticks(rotation='vertical')
plt.title("Sum of global sales per publisher (>2010)")

plt.show()

# %% [markdown]
# # Klasteryzacja
